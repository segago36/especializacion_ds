# %%
# Implementación incorrecta
class Rectangulo:
    def __init__(self, ancho, altura):
        self.ancho = ancho
        self.altura = altura

    def establecer_ancho(self, ancho):
        self.ancho = ancho

    def establecer_altura(self, altura):
        self.altura = altura

    def area(self):
        return self.ancho * self.altura


class Cuadrado(Rectangulo):
    def __init__(self, lado):
        super().__init__(lado, lado)

    def establecer_ancho(self, ancho):
        self.lado = ancho
        self.altura = ancho

    def establecer_altura(self, altura):
        self.lado = altura
        self.altura = altura


def area_cuadrado_con_error(cuadrado):
    cuadrado.establecer_ancho(4)
    cuadrado.establecer_altura(5)
    return cuadrado.area()


rectangulo = Rectangulo(2, 3)
print("Área del rectángulo:", rectangulo.area())

cuadrado = Cuadrado(2)
print("Área del cuadrado (antes de error):", cuadrado.area())
print("Área del cuadrado (después de error):", area_cuadrado_con_error(cuadrado))

# %%
# Implementación corregida 
class Forma:
    def area(self):
        pass


class Rectangulo(Forma):
    def __init__(self, ancho, altura):
        self.ancho = ancho
        self.altura = altura

    def establecer_ancho(self, ancho):
        self.ancho = ancho

    def establecer_altura(self, altura):
        self.altura = altura

    def area(self):
        return self.ancho * self.altura


class Cuadrado(Forma):
    def __init__(self, lado):
        self.lado = lado

    def establecer_lado(self, lado):
        self.lado = lado

    def area(self):
        return self.lado ** 2

# %%
rectangulo = Rectangulo(2, 3)
print("Área del rectángulo:", rectangulo.area())

cuadrado = Cuadrado(2)
print("Área del cuadrado:", cuadrado.area())
